# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("V:/Capstone/Data/MergedFromRDS.csv")
# Out:
# C:\Users\niraj\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (5,6,10,11,19,46,51,52,53) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#    Unnamed: 0        Date Activity     Event Name        F&B  Retail.x  \
# 0           1  2021-09-09    CONCT  Blake Shelton  263509.53  16684.34
# 1           2  2021-09-09    CONCT  Blake Shelton  263509.53  16684.34
# 2           3  2021-09-09    CONCT  Blake Shelton  263509.53  16684.34
# 3           4  2021-09-09    CONCT  Blake Shelton  263509.53  16684.34
# 4           5  2021-09-09    CONCT  Blake Shelton  263509.53  16684.34
#
#         CR    Revenue    Attd.     F&B PC  ... ...32 ...33  \
# 0  3893.17  284087.04  12003.0  21.953639  ...   NaN   NaN
# 1  3893.17  284087.04  12003.0  21.953639  ...   NaN   NaN
# 2  3893.17  284087.04  12003.0  21.953639  ...   NaN   NaN
# 3  3893.17  284087.04  12003.0  21.953639  ...   NaN   NaN
# 4  3893.17  284087.04  12003.0  21.953639  ...   NaN   NaN
#
#                   Team     Location Stand Type Service Style  \
# 0  Nashville Predators  Concessions        Bar      Standard
# ...

# %%
df = df.drop(columns = 'Unnamed: 0')

# %%
df1 = df.drop(['...26', '...27', '...28',
       '...29', '...30', '...31', '...32', '...33'], 1)

# %%
df1.head()
# Out:
#          Date Activity     Event Name        F&B  Retail.x       CR  \
# 0  2021-09-09    CONCT  Blake Shelton  263509.53  16684.34  3893.17
# 1  2021-09-09    CONCT  Blake Shelton  263509.53  16684.34  3893.17
# 2  2021-09-09    CONCT  Blake Shelton  263509.53  16684.34  3893.17
# 3  2021-09-09    CONCT  Blake Shelton  263509.53  16684.34  3893.17
# 4  2021-09-09    CONCT  Blake Shelton  263509.53  16684.34  3893.17
#
#      Revenue    Attd.     F&B PC    Ret PC  ... Product - Cat 3  \
# 0  284087.04  12003.0  21.953639  1.390014  ...       16 Ounces
# 1  284087.04  12003.0  21.953639  1.390014  ...       16 Ounces
# 2  284087.04  12003.0  21.953639  1.390014  ...       20 Ounces
# 3  284087.04  12003.0  21.953639  1.390014  ...       24 Ounces
# 4  284087.04  12003.0  21.953639  1.390014  ...       24 Ounces
#
#    Product - Cat 4                 Team     Location Stand Type Service Style  \
# 0           No Cat  Nashville Predators  Concessions        Bar      Standard
# ...

# %%
df1.columns
# Out:
# Index(['Date', 'Activity', 'Event Name', 'F&B', 'Retail.x', 'CR', 'Revenue',
#        'Attd.', 'F&B PC', 'Ret PC', 'CR PC', 'Total PC', 'TH_Loc',
#        'location_id', 'cost_center_name', 'source_system', 'item_name',
#        'item_id', 'is_tax_exempt', 'qty', 'amount', 'Transaction Check',
#        'Price', 'Item Cost', 'Season', 'Event - Type Category',
#        'Event - Category', 'Game Tier', 'Location - Category',
#        'Location - Sub-Category', 'Location - Concept', 'Location - Brand',
#        'Product - Cat 0', 'Product - Cat 1', 'Product - Cat 2',
#        'Product - Cat 3', 'Product - Cat 4', 'Team', 'Location', 'Stand Type',
#        'Service Style', 'Branded/Non-Branded', 'Retail.y', 'Section',
#        'Concept'],
#       dtype='object')

# %%
df1['Retail.y'].isna().sum()
# Out:
# 243367

# %%
df1['Retail.y'].unique()
# Out:
# array(['No', nan, 'yes', 'Yes', 'no', 'NO'], dtype=object)

# %%
df1['Branded/Non-Branded'].value_counts()
# Out:
# Non-Branded        539386
# Branded            160670
# Branded Partner     42009
# In House Brand      12952
# market               1330
# Name: Branded/Non-Branded, dtype: int64

# %%
df1.Activity.unique()
# Out:
# array(['CONCT', 'ICESH', 'NHLPR', 'WREST', 'NHLRG', 'RELGN', 'MUSAW',
#        'COMIC', 'EVENT', 'ICECO', 'MOTOR', 'CBKPT', 'FMILY', 'NFLPR',
#        'NFLRG', 'NFLPO', 'CFBOT', 'MLBRG', nan, 'TENNS', 'NBAPR', 'NBARG',
#        'TOURN', 'HKYOT', 'CHKOT', 'NBAPT'], dtype=object)

# %%
df2 = df1.drop(['Event Name','location_id','cost_center_name','Transaction Check','Season','Event - Type Category','Event - Category','Game Tier','Location - Category','Location - Sub-Category','Location - Concept','Location - Brand','Team','Section'], 1)

# %%
df2.head()
# Out:
#          Date Activity        F&B  Retail.x       CR    Revenue    Attd.  \
# 0  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04  12003.0
# 1  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04  12003.0
# 2  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04  12003.0
# 3  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04  12003.0
# 4  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04  12003.0
#
#       F&B PC    Ret PC    CR PC  ...  Product - Cat 1 Product - Cat 2  \
# 0  21.953639  1.390014  0.32435  ...          Bottled    Energy Drink
# 1  21.953639  1.390014  0.32435  ...         Packaged         Premium
# 2  21.953639  1.390014  0.32435  ...          Bottled           Water
# 3  21.953639  1.390014  0.32435  ...         Packaged        Domestic
# 4  21.953639  1.390014  0.32435  ...         Packaged        Domestic
#
#   Product - Cat 3 Product - Cat 4     Location Stand Type  Service Style  \
# ...

# %%
df2['Retail.y'] = df2['Retail.y'].str.upper()

# %%
df2.head()
# Out:
#          Date Activity        F&B  Retail.x       CR    Revenue    Attd.  \
# 0  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04  12003.0
# 1  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04  12003.0
# 2  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04  12003.0
# 3  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04  12003.0
# 4  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04  12003.0
#
#       F&B PC    Ret PC    CR PC  ...  Product - Cat 1 Product - Cat 2  \
# 0  21.953639  1.390014  0.32435  ...          Bottled    Energy Drink
# 1  21.953639  1.390014  0.32435  ...         Packaged         Premium
# 2  21.953639  1.390014  0.32435  ...          Bottled           Water
# 3  21.953639  1.390014  0.32435  ...         Packaged        Domestic
# 4  21.953639  1.390014  0.32435  ...         Packaged        Domestic
#
#   Product - Cat 3 Product - Cat 4     Location Stand Type  Service Style  \
# ...

# %%
dfBs = df2.loc[df['TH_Loc'] == 'Bridgestone'] # change location

# %%
dfBs.head()
# Out:
#          Date Activity        F&B  Retail.x       CR    Revenue    Attd.  \
# 0  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04  12003.0
# 1  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04  12003.0
# 2  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04  12003.0
# 3  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04  12003.0
# 4  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04  12003.0
#
#       F&B PC    Ret PC    CR PC  ...  Product - Cat 1 Product - Cat 2  \
# 0  21.953639  1.390014  0.32435  ...          Bottled    Energy Drink
# 1  21.953639  1.390014  0.32435  ...         Packaged         Premium
# 2  21.953639  1.390014  0.32435  ...          Bottled           Water
# 3  21.953639  1.390014  0.32435  ...         Packaged        Domestic
# 4  21.953639  1.390014  0.32435  ...         Packaged        Domestic
#
#   Product - Cat 3 Product - Cat 4     Location Stand Type  Service Style  \
# ...

# %%
dfBs.isna().sum().sum()
# Out:
# 673141

# %%
dfBs.columns
# Out:
# Index(['Date', 'Activity', 'F&B', 'Retail.x', 'CR', 'Revenue', 'Attd.',
#        'F&B PC', 'Ret PC', 'CR PC', 'Total PC', 'TH_Loc', 'source_system',
#        'item_name', 'item_id', 'is_tax_exempt', 'qty', 'amount', 'Price',
#        'Item Cost', 'Product - Cat 0', 'Product - Cat 1', 'Product - Cat 2',
#        'Product - Cat 3', 'Product - Cat 4', 'Location', 'Stand Type',
#        'Service Style', 'Branded/Non-Branded', 'Retail.y', 'Concept'],
#       dtype='object')

# %%
dfBs1 = dfBs.copy()

# %%
dfBs1['Branded/Non-Branded'] = dfBs1['Branded/Non-Branded'].fillna('Other')

# %%
dfBs1['Stand Type'] = dfBs1['Stand Type'].fillna('Other')

# %%
dfBs1.Activity.unique()
# Out:
# array(['CONCT', 'ICESH', 'NHLPR', 'WREST', 'NHLRG', 'RELGN', 'MUSAW',
#        'COMIC', 'EVENT', 'ICECO', 'MOTOR', 'CBKPT', 'FMILY'], dtype=object)

# %%
# change the activity and product

# %%
dfBsAlWr1 = dfBs1.loc[(dfBs1['Activity'] == 'WREST') & (dfBs1['Product - Cat 0'] == "Alcohol")] 
dfBsAlCo1 = dfBs1.loc[(dfBs1['Activity'] == 'CONCT') & (dfBs1['Product - Cat 0'] == "Alcohol")]

# %%
dfBsReWr1 = dfBs1.loc[(dfBs1['Activity'] == 'WREST') & (dfBs1['Product - Cat 0'] == "Retail")] 
dfBsReCo1 = dfBs1.loc[(dfBs1['Activity'] == 'CONCT') & (dfBs1['Product - Cat 0'] == "Retail")]

# %%
dfBsAlWr1.reset_index(inplace = True)
dfBsAlCo1.reset_index(inplace = True)
dfBsReWr1.reset_index(inplace = True)
dfBsReCo1.reset_index(inplace = True)

# %%
dfBsAlWr1.head()
# Out:
#    index        Date Activity       F&B Retail.x       CR   Revenue   Attd.  \
# 0  16699  2021-10-04    WREST  78662.09      0.0  1519.17  80181.26  4867.0
# 1  16700  2021-10-04    WREST  78662.09      0.0  1519.17  80181.26  4867.0
# 2  16702  2021-10-04    WREST  78662.09      0.0  1519.17  80181.26  4867.0
# 3  16703  2021-10-04    WREST  78662.09      0.0  1519.17  80181.26  4867.0
# 4  16704  2021-10-04    WREST  78662.09      0.0  1519.17  80181.26  4867.0
#
#       F&B PC Ret PC  ... Product - Cat 1  Product - Cat 2 Product - Cat 3  \
# 0  16.162336    0.0  ...        Packaged          Premium       16 Ounces
# 1  16.162336    0.0  ...           Draft            Craft       16 Ounces
# 2  16.162336    0.0  ...        Packaged         Domestic       24 Ounces
# 3  16.162336    0.0  ...           Draft            Craft       24 Ounces
# 4  16.162336    0.0  ...           Draft            Craft       24 Ounces
#
# ...

# %%
dfBsReCo1.head()
# Out:
#    index        Date Activity        F&B  Retail.x       CR    Revenue  \
# 0     47  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04
# 1     87  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04
# 2     89  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04
# 3    183  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04
# 4    250  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04
#
#      Attd.     F&B PC    Ret PC  ... Product - Cat 1  Product - Cat 2  \
# 0  12003.0  21.953639  1.390014  ...          Retail           Retail
# 1  12003.0  21.953639  1.390014  ...          Retail           Retail
# 2  12003.0  21.953639  1.390014  ...          Retail           Retail
# 3  12003.0  21.953639  1.390014  ...          Retail           Retail
# 4  12003.0  21.953639  1.390014  ...          Retail           Retail
#
#   Product - Cat 3 Product - Cat 4     Location  Stand Type Service Style  \
# ...

# %%
dfBsAlWr1.head()
# Out:
#    index        Date Activity       F&B Retail.x       CR   Revenue   Attd.  \
# 0  16699  2021-10-04    WREST  78662.09      0.0  1519.17  80181.26  4867.0
# 1  16700  2021-10-04    WREST  78662.09      0.0  1519.17  80181.26  4867.0
# 2  16702  2021-10-04    WREST  78662.09      0.0  1519.17  80181.26  4867.0
# 3  16703  2021-10-04    WREST  78662.09      0.0  1519.17  80181.26  4867.0
# 4  16704  2021-10-04    WREST  78662.09      0.0  1519.17  80181.26  4867.0
#
#       F&B PC Ret PC  ... Product - Cat 1  Product - Cat 2 Product - Cat 3  \
# 0  16.162336    0.0  ...        Packaged          Premium       16 Ounces
# 1  16.162336    0.0  ...           Draft            Craft       16 Ounces
# 2  16.162336    0.0  ...        Packaged         Domestic       24 Ounces
# 3  16.162336    0.0  ...           Draft            Craft       24 Ounces
# 4  16.162336    0.0  ...           Draft            Craft       24 Ounces
#
# ...

# %%
dfBsReCo1.head()
# Out:
#    index        Date Activity        F&B  Retail.x       CR    Revenue  \
# 0     47  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04
# 1     87  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04
# 2     89  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04
# 3    183  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04
# 4    250  2021-09-09    CONCT  263509.53  16684.34  3893.17  284087.04
#
#      Attd.     F&B PC    Ret PC  ... Product - Cat 1  Product - Cat 2  \
# 0  12003.0  21.953639  1.390014  ...          Retail           Retail
# 1  12003.0  21.953639  1.390014  ...          Retail           Retail
# 2  12003.0  21.953639  1.390014  ...          Retail           Retail
# 3  12003.0  21.953639  1.390014  ...          Retail           Retail
# 4  12003.0  21.953639  1.390014  ...          Retail           Retail
#
#   Product - Cat 3 Product - Cat 4     Location  Stand Type Service Style  \
# ...

# %%
# change the datframe names properly

# %%
dfBsAlWr1['avgPurchase'] = dfBsAlWr1['qty'] /dfBsAlWr1['Attd.']
dfBsAlCo1['avgPurchase'] = dfBsAlCo1['qty'] /dfBsAlCo1['Attd.']
dfBsReWr1['avgPurchase'] = dfBsReWr1['qty'] /dfBsReWr1['Attd.']
dfBsReCo1['avgPurchase'] = dfBsReCo1['qty'] /dfBsReCo1['Attd.']
# Out:
# <ipython-input-33-d36498518ab4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfBsAlWr1['avgPurchase'] = dfBsAlWr1['qty'] /dfBsAlWr1['Attd.']
# <ipython-input-33-d36498518ab4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfBsAlCo1['avgPurchase'] = dfBsAlCo1['qty'] /dfBsAlCo1['Attd.']
# <ipython-input-33-d36498518ab4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# change capital b to small b eg : Hp to hp or Td to td

# %%
dfbsAlWr = dfBsAlWr1.drop(['index','Item Cost','Product - Cat 0','Concept','is_tax_exempt','Activity','Date','TH_Loc','item_id','item_name','Product - Cat 4','Location','Service Style','Retail.y'],axis =1)
dfbsAlCo = dfBsAlCo1.drop(['index','Item Cost','Product - Cat 0','Concept','is_tax_exempt','Activity','Date','TH_Loc','item_id','item_name','Product - Cat 4','Location','Service Style','Retail.y'],axis =1)
dfbsReWr = dfBsReWr1.drop(['index','Item Cost','Product - Cat 0','Concept','is_tax_exempt','Activity','Date','TH_Loc','item_id','item_name','Product - Cat 4','Location','Service Style','Retail.y'],axis =1)
dfbsReCo = dfBsReCo1.drop(['index','Item Cost','Product - Cat 0','Concept','is_tax_exempt','Activity','Date','TH_Loc','item_id','item_name','Product - Cat 4','Location','Service Style','Retail.y'],axis =1)

# %%
dfbsAlWr1  = dfbsAlWr.copy()
dfbsAlCo1 = dfbsAlCo.copy()
dfbsReWr1 = dfbsReWr.copy()
dfbsReCo1 =  dfbsReCo.copy()

# %%
dfbsAlWr1['Product - Cat 3'].value_counts()
# Out:
# Regular        304
# 25 Ounces      229
# 24 Ounces      196
# 16 Ounces      194
# 20 Ounces       15
# 3.5oz            7
# 18.5oz           6
# 19.2 Ounces      3
# 12 Ounces        2
# Name: Product - Cat 3, dtype: int64

# %%
dfbsAlCo1['Product - Cat 3'].value_counts()
# Out:
# Regular        15341
# 25 Ounces       6326
# 16 Ounces       6297
# 24 Ounces       5005
# 20 Ounces        325
# 19.2 Ounces      273
# 18.5oz           176
# 12 Ounces         87
# 3.5oz             75
# Large              5
# 11.5oz             5
# Name: Product - Cat 3, dtype: int64

# %%
dfbsReWr1['Product - Cat 3'].value_counts()
# Out:
# Regular     157
# Souvenir     34
# Large         6
# Small         3
# 30oz          1
# Name: Product - Cat 3, dtype: int64

# %%
dfbsReCo1['Product - Cat 3'].value_counts()
# Out:
# Regular      4113
# Souvenir      714
# Large         249
# Small         123
# 12 Ounces      37
# 30oz            3
# Name: Product - Cat 3, dtype: int64

# %%
dfbsAlWr1 = dfbsAlWr1.drop(['F&B', 'Retail.x', 'CR', 'Revenue', 'Attd.', 'F&B PC', 'Ret PC','CR PC', 'Total PC'], axis =1)
dfbsAlCo1 = dfbsAlCo1.drop(['F&B', 'Retail.x', 'CR', 'Revenue', 'Attd.', 'F&B PC', 'Ret PC','CR PC', 'Total PC'], axis =1)
dfbsReWr1 = dfbsReWr1.drop(['F&B', 'Retail.x', 'CR', 'Revenue', 'Attd.', 'F&B PC', 'Ret PC','CR PC', 'Total PC'], axis =1)
dfbsReCo1 = dfbsReCo1.drop(['F&B', 'Retail.x', 'CR', 'Revenue', 'Attd.', 'F&B PC', 'Ret PC','CR PC', 'Total PC'], axis =1)

# %%
# only for alcohol 
dfbsAlWr1['Product - Cat 3'] = ['Small' if ( x == '3.5oz' or x == '11.5oz' or x == '12 Ounces' ) else 'Regular' if ( x == '16 Ounces'  or x == '20 Ounces' or x == '19.2 Ounces' or x == '18.5oz') else 'Large' for x in dfbsAlWr1['Product - Cat 3']]
dfbsAlCo1['Product - Cat 3'] = ['Small' if ( x == '3.5oz' or x == '11.5oz' or x == '12 Ounces' ) else 'Regular' if (x == '16 Ounces'  or x == '20 Ounces' or x == '19.2 Ounces' or x == '18.5oz' or x == '19.2 Ounces') else 'Large' for x in dfbsAlCo1['Product - Cat 3']]

# %%
# only for retail 
dfbsReWr1['Product - Cat 3'] = ['Small' if ( x == 'Souvenir' ) else x for x in dfbsReWr1['Product - Cat 3']]
dfbsReWr1['Product - Cat 3'] = ['Large' if ( x == '30oz' ) else x  for x in dfbsReWr1['Product - Cat 3']]


dfbsReCo1['Product - Cat 3'] = ['Small' if ( x == 'Souvenir' or x == '12 Ounces') else x  for x in dfbsReCo1['Product - Cat 3']]
dfbsReCo1['Product - Cat 3'] = ['Large' if ( x == '30oz') else x  for x in dfbsReCo1['Product - Cat 3']]

# %%
dfbsAlWr1.isna().sum().sum()
# Out:
# 0

# %%
dfbsAlCo1.isna().sum().sum()
# Out:
# 0

# %%
dfbsReWr1.isna().sum().sum()
# Out:
# 0

# %%
dfbsReCo1.isna().sum().sum()
# Out:
# 0

# %%
from kmodes.kprototypes import KPrototypes

# %%
dfbsAlWr1.head()
# Out:
#   source_system  qty  amount  Price Product - Cat 1 Product - Cat 2  \
# 0      appetize    4    25.0   6.25        Packaged         Premium
# 1      appetize    5    50.0  10.00           Draft           Craft
# 2      appetize    6    78.0  13.00        Packaged        Domestic
# 3      appetize    5    65.0  13.00           Draft           Craft
# 4      appetize    6    78.0  13.00           Draft           Craft
#
#   Product - Cat 3 Stand Type Branded/Non-Branded  avgPurchase
# 0         Regular        Bar             Branded     0.000822
# 1         Regular        Bar             Branded     0.001027
# 2           Large        Bar             Branded     0.001233
# 3           Large        Bar             Branded     0.001027
# 4           Large        Bar             Branded     0.001233

# %%
dfbsAlCo1.head()
# Out:
#   source_system  qty  amount  Price Product - Cat 1 Product - Cat 2  \
# 0      appetize    1     6.5    6.5        Packaged         Premium
# 1      appetize   49   686.0   14.0        Packaged        Domestic
# 2      appetize   38   532.0   14.0        Packaged        Domestic
# 3      appetize    1    14.0   14.0           Draft           Craft
# 4      appetize    3    42.0   14.0           Draft           Craft
#
#   Product - Cat 3 Stand Type Branded/Non-Branded  avgPurchase
# 0         Regular        Bar             Branded     0.000083
# 1           Large        Bar             Branded     0.004082
# 2           Large        Bar             Branded     0.003166
# 3           Large        Bar             Branded     0.000083
# 4           Large        Bar             Branded     0.000250

# %%
dfbsReWr1.head()
# Out:
#   source_system  qty  amount  Price Product - Cat 1 Product - Cat 2  \
# 0      appetize    1     6.0    6.0          Retail          Retail
# 1      appetize   18   360.0   20.0          Retail          Retail
# 2      appetize    5    32.5    6.5          Retail          Retail
# 3      appetize    4    26.0    6.5          Retail          Retail
# 4      appetize    1     5.0    5.0          Retail          Retail
#
#   Product - Cat 3 Stand Type Branded/Non-Branded  avgPurchase
# 0           Large        Bar             Branded     0.000205
# 1           Small        Bar             Branded     0.003698
# 2           Small        Bar             Branded     0.001027
# 3           Small        Bar               Other     0.000822
# 4           Small   Portable               Other     0.000205

# %%
dfbsReCo1.head()
# Out:
#   source_system  qty  amount  Price Product - Cat 1 Product - Cat 2  \
# 0      appetize    1     1.0    1.0          Retail          Retail
# 1      appetize    1     6.0    6.0          Retail          Retail
# 2      appetize    2    10.0    5.0          Retail          Retail
# 3      appetize    1     6.0    6.0          Retail          Retail
# 4      appetize    9    54.0    6.0          Retail          Retail
#
#   Product - Cat 3 Stand Type Branded/Non-Branded  avgPurchase
# 0         Regular        Bar         Non-Branded     0.000083
# 1           Large        Bar             Branded     0.000083
# 2           Small        Bar             Branded     0.000167
# 3           Large        Bar             Branded     0.000083
# 4           Large        Bar             Branded     0.000750

# %%
from kmodes.kprototypes import KPrototypes

# %%
mark_arrays_AlcoholWrestling = dfbsAlWr1.values
mark_arrays_AlcoholConcert = dfbsAlCo1.values
mark_arrays_RetailWrestling = dfbsReWr1.values
mark_arrays_RetailConcert = dfbsReCo1.values

# %%
# for alchol wrestling
mark_arrays_AlcoholWrestling[:,1] = mark_arrays_AlcoholWrestling[:,1].astype(float)
mark_arrays_AlcoholWrestling[:,2] = mark_arrays_AlcoholWrestling[:,2].astype(float)
mark_arrays_AlcoholWrestling[:,3] = mark_arrays_AlcoholWrestling[:,3].astype(float)
mark_arrays_AlcoholWrestling[:,9] = mark_arrays_AlcoholWrestling[:,9].astype(float)

# %%
# for alchol Concert
mark_arrays_AlcoholConcert[:,1] = mark_arrays_AlcoholConcert[:,1].astype(float)
mark_arrays_AlcoholConcert[:,2] = mark_arrays_AlcoholConcert[:,2].astype(float)
mark_arrays_AlcoholConcert[:,3] = mark_arrays_AlcoholConcert[:,3].astype(float)
mark_arrays_AlcoholConcert[:,9] = mark_arrays_AlcoholConcert[:,9].astype(float)

# %%
# for Retail wrestling
mark_arrays_RetailWrestling[:,1] = mark_arrays_RetailWrestling[:,1].astype(float)
mark_arrays_RetailWrestling[:,2] = mark_arrays_RetailWrestling[:,2].astype(float)
mark_arrays_RetailWrestling[:,3] = mark_arrays_RetailWrestling[:,3].astype(float)
mark_arrays_RetailWrestling[:,9] = mark_arrays_RetailWrestling[:,9].astype(float)

# %%
# for Retail Concert
mark_arrays_RetailConcert[:,1] = mark_arrays_RetailConcert[:,1].astype(float)
mark_arrays_RetailConcert[:,2] = mark_arrays_RetailConcert[:,2].astype(float)
mark_arrays_RetailConcert[:,3] = mark_arrays_RetailConcert[:,3].astype(float)
mark_arrays_RetailConcert[:,9] = mark_arrays_RetailConcert[:,9].astype(float)

# %%
mark_arrays_AlcoholWrestling
# Out:
# array([['appetize', 4.0, 25.0, ..., 'Bar', 'Branded',
#         0.0008218615163344976],
#        ['appetize', 5.0, 50.0, ..., 'Bar', 'Branded',
#         0.001027326895418122],
#        ['appetize', 6.0, 78.0, ..., 'Bar', 'Branded',
#         0.0012327922745017466],
#        ...,
#        ['appetize', 15.0, 135.0, ..., 'Restaurant', 'Other',
#         0.0022932273352698363],
#        ['appetize', 1.0, 8.0, ..., 'Restaurant', 'Other',
#         0.00015288182235132243],
#        ['appetize', 3.0, 33.0, ..., 'Restaurant', 'Other',
#         0.00045864546705396726]], dtype=object)

# %%
kproto = KPrototypes(n_clusters=3 , verbose = 2 , max_iter = 20) 
clusters = kproto.fit_predict(mark_arrays_AlcoholWrestling,categorical=[0,4,5,6,7,8])
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 206, ncost: 2327518.9940753384
# Run: 1, iteration: 2/20, moves: 90, ncost: 2171326.737763536
# Run: 1, iteration: 3/20, moves: 69, ncost: 2028913.4121418446
# Run: 1, iteration: 4/20, moves: 41, ncost: 1930159.4323755486
# Run: 1, iteration: 5/20, moves: 28, ncost: 1862251.2388758813
# Run: 1, iteration: 6/20, moves: 28, ncost: 1835881.2687983543
# Run: 1, iteration: 7/20, moves: 12, ncost: 1829430.8740348697
# Run: 1, iteration: 8/20, moves: 5, ncost: 1828663.320715858
# Run: 1, iteration: 9/20, moves: 0, ncost: 1828663.320715858
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 52, ncost: 1833600.0021727942
# Run: 2, iteration: 2/20, moves: 3, ncost: 1828663.320715858
# ...

# %%
print(kproto.cluster_centroids_)
# Out:
# [['12.718918918918918' '180.8918918918919' '14.877927927891891'
#   '0.0022108201116261012' 'appetize' 'Packaged' 'Domestic' 'Large' 'Bar'
#   'Branded']
#  ['32.78260869565217' '476.9130434782609' '14.486578738260869'
#   '0.005684019988356256' 'appetize' 'Packaged' 'Domestic' 'Large'
#   'Portable' 'Branded']
#  ['2.913101604278075' '37.63622994652407' '13.26741310160829'
#   '0.0005252198012719627' 'appetize' 'Non-Beer' 'Domestic' 'Large' 'Bar'
#   'Branded']]

# %%
cluster_dict = []
for c in clusters:
    cluster_dict.append(c)

# %%
dfbsAlWr['segment'] = cluster_dict

# %%
dfbsAlWr[dfbsAlWr['segment'] == 0].head(10)
# Out:
#          F&B Retail.x       CR   Revenue   Attd.     F&B PC Ret PC     CR PC  \
# 5   78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 6   78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 7   78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 17  78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 24  78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 25  78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 26  78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 28  78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 35  78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 36  78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
#
#      Total PC source_system  qty  amount  Price Product - Cat 1  \
# ...

# %%
dfbsAlWr[dfbsAlWr['segment'] == 1].head(10)
# Out:
#           F&B Retail.x       CR    Revenue   Attd.     F&B PC    Ret PC  \
# 41   78662.09      0.0  1519.17   80181.26  4867.0  16.162336       0.0
# 102  78662.09      0.0  1519.17   80181.26  4867.0  16.162336       0.0
# 110  78662.09      0.0  1519.17   80181.26  4867.0  16.162336       0.0
# 118  78662.09      0.0  1519.17   80181.26  4867.0  16.162336       0.0
# 230  78662.09      0.0  1519.17   80181.26  4867.0  16.162336       0.0
# 232  78662.09      0.0  1519.17   80181.26  4867.0  16.162336       0.0
# 240  78662.09      0.0  1519.17   80181.26  4867.0  16.162336       0.0
# 308  78662.09      0.0  1519.17   80181.26  4867.0  16.162336       0.0
# 470  78662.09      0.0  1519.17   80181.26  4867.0  16.162336       0.0
# 521  97354.92  8722.37   514.42  106591.71  6541.0  14.883798  1.333492
#
#         CR PC   Total PC source_system  qty  amount      Price  \
# 41   0.312137  16.474473      appetize   23   460.0  20.000000
# ...

# %%
dfbsAlWr[dfbsAlWr['segment'] == 2].head(10)
# Out:
#          F&B Retail.x       CR   Revenue   Attd.     F&B PC Ret PC     CR PC  \
# 0   78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 1   78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 2   78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 3   78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 4   78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 8   78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 9   78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 10  78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 11  78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 12  78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
#
#      Total PC source_system  qty  amount  Price Product - Cat 1  \
# ...

# %%
mark_arrays_AlcoholConcert
# Out:
# array([['appetize', 1.0, 6.5, ..., 'Bar', 'Branded',
#         8.331250520703157e-05],
#        ['appetize', 49.0, 686.0, ..., 'Bar', 'Branded',
#         0.004082312755144547],
#        ['appetize', 38.0, 532.0, ..., 'Bar', 'Branded',
#         0.0031658751978672],
#        ...,
#        ['appetize', 5.0, 35.0, ..., 'Restaurant', 'Other',
#         0.0005209961446285298],
#        ['appetize', 1.0, 11.0, ..., 'Restaurant', 'Other',
#         0.00010419922892570594],
#        ['appetize', 3.0, 18.0, ..., 'Restaurant', 'Other',
#         0.00031259768677711783]], dtype=object)

# %%
kproto = KPrototypes(n_clusters=3 , verbose = 2 , max_iter = 20) 
clusters = kproto.fit_predict(mark_arrays_AlcoholConcert,categorical=[0,4,5,6,7,8])
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 4670, ncost: 1235899632.2411149
# Run: 1, iteration: 2/20, moves: 3990, ncost: 952925390.5325185
# Run: 1, iteration: 3/20, moves: 2631, ncost: 801487528.872109
# Run: 1, iteration: 4/20, moves: 1515, ncost: 744585333.6706681
# Run: 1, iteration: 5/20, moves: 940, ncost: 715496043.4431949
# Run: 1, iteration: 6/20, moves: 572, ncost: 700967585.5040303
# Run: 1, iteration: 7/20, moves: 384, ncost: 694897910.7729242
# ...

# %%
print(kproto.cluster_centroids_)
# Out:
# [['5.6184435388458' '77.7655399631918' '13.804309498447257'
#   '0.0005212513475807764' 'appetize' 'Non-Beer' 'Domestic' 'Large' 'Bar'
#   'Branded']
#  ['126.46216216216216' '2286.1243243243243' '18.897297297297257'
#   '0.009495982428753621' 'appetize' 'Non-Beer' "dbl - tito's" 'Large'
#   'Bar' 'Branded']
#  ['40.98299647096567' '641.1367500802053' '16.250626651803028'
#   '0.003369719716510856' 'appetize' 'Non-Beer' 'Seltzer' 'Large' 'Bar'
#   'Branded']]

# %%
cluster_dict = []
for c in clusters:
    cluster_dict.append(c)

# %%
dfbsAlCo['segment'] = cluster_dict

# %%
dfbsAlCo[dfbsAlCo['segment'] == 0].head(10)
# Out:
#           F&B  Retail.x       CR    Revenue    Attd.     F&B PC    Ret PC  \
# 0   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 3   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 4   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 9   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 10  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 11  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 12  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 14  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 16  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 17  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
#
#       CR PC   Total PC source_system  qty  amount  Price Product - Cat 1  \
# 0   0.32435  23.668003      appetize    1     6.5    6.5        Packaged
# ...

# %%
dfbsAlCo[dfbsAlCo['segment'] == 1].head(10)
# Out:
#             F&B  Retail.x       CR    Revenue    Attd.     F&B PC    Ret PC  \
# 78    263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 131   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 169   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 279   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 386   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 434   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 504   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 551   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 1028  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 1497  222766.89  13033.67  2777.49  238578.05   9386.0  23.733954  1.388629
#
#          CR PC   Total PC source_system  qty  amount  Price Product - Cat 1  \
# ...

# %%
dfbsAlCo[dfbsAlCo['segment'] == 2].head(10)
# Out:
#           F&B  Retail.x       CR    Revenue    Attd.     F&B PC    Ret PC  \
# 1   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 2   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 5   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 6   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 7   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 8   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 13  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 15  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 20  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 22  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
#
#       CR PC   Total PC source_system  qty  amount  Price Product - Cat 1  \
# 1   0.32435  23.668003      appetize   49   686.0   14.0        Packaged
# ...

# %%
mark_arrays_RetailWrestling
# Out:
# array([['appetize', 1.0, 6.0, ..., 'Bar', 'Branded',
#         0.0002054653790836244],
#        ['appetize', 18.0, 360.0, ..., 'Bar', 'Branded',
#         0.0036983768235052394],
#        ['appetize', 5.0, 32.5, ..., 'Bar', 'Branded',
#         0.001027326895418122],
#        ...,
#        ['netsuite', 1.0, 49.99, ..., 'Other', 'Other',
#         0.00015288182235132243],
#        ['netsuite', 1.0, 84.99, ..., 'Other', 'Other',
#         0.00015288182235132243],
#        ['netsuite', 2.0, 179.98, ..., 'Other', 'Other',
#         0.00030576364470264486]], dtype=object)

# %%
kproto = KPrototypes(n_clusters=3 , verbose = 2 , max_iter = 20) 
clusters = kproto.fit_predict(mark_arrays_RetailWrestling,categorical=[0,4,5,6,7,8])
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 22, ncost: 69738854.94994655
# Run: 1, iteration: 2/20, moves: 11, ncost: 59561455.49260975
# Run: 1, iteration: 3/20, moves: 5, ncost: 50152772.66083057
# Run: 1, iteration: 4/20, moves: 8, ncost: 34888919.396454535
# Run: 1, iteration: 5/20, moves: 2, ncost: 29083482.410669286
# Run: 1, iteration: 6/20, moves: 2, ncost: 28180378.696372963
# Run: 1, iteration: 7/20, moves: 0, ncost: 28180378.696372963
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 131, ncost: 76775014.66520554
# Run: 2, iteration: 2/20, moves: 40, ncost: 62275968.566289544
# ...

# %%
print(kproto.cluster_centroids_)
# Out:
# [['8.136125654450261' '146.95020942408365' '56.00659609299467'
#   '0.0014880626531701914' 'netsuite' 'Retail' 'Retail' 'Regular' 'Other'
#   'Other']
#  ['47.666666666666664' '9532.856666666667' '199.9900000000001'
#   '0.007287366865413026' 'netsuite' 'Retail' 'Retail' 'Regular' 'Other'
#   'Other']
#  ['18.714285714285715' '3742.669999999998' '199.9900000000001'
#   '0.002861074104003317' 'netsuite' 'Retail' 'Retail' 'Regular' 'Other'
#   'Other']]

# %%
cluster_dict = []
for c in clusters:
    cluster_dict.append(c)

# %%
dfbsReWr['segment'] = cluster_dict

# %%
dfbsReWr[dfbsReWr['segment'] == 0].head(10)
# Out:
#         F&B Retail.x       CR   Revenue   Attd.     F&B PC Ret PC     CR PC  \
# 0  78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 1  78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 2  78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 3  78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 4  78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 5  78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 6  78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 7  78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 8  78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
# 9  78662.09      0.0  1519.17  80181.26  4867.0  16.162336    0.0  0.312137
#
#     Total PC source_system  qty  amount  Price Product - Cat 1  \
# 0  16.474473      appetize    1    6.00   6.00          Retail
# ...

# %%
dfbsReWr[dfbsReWr['segment'] == 1].head(10)
# Out:
#          F&B Retail.x      CR    Revenue   Attd.     F&B PC    Ret PC  \
# 67  97354.92  8722.37  514.42  106591.71  6541.0  14.883798  1.333492
# 69  97354.92  8722.37  514.42  106591.71  6541.0  14.883798  1.333492
# 71  97354.92  8722.37  514.42  106591.71  6541.0  14.883798  1.333492
#
#        CR PC   Total PC source_system  qty    amount   Price Product - Cat 1  \
# 67  0.078645  16.295935      netsuite   57  11399.43  199.99          Retail
# 69  0.078645  16.295935      netsuite   47   9399.53  199.99          Retail
# 71  0.078645  16.295935      netsuite   39   7799.61  199.99          Retail
#
#    Product - Cat 2 Product - Cat 3 Stand Type Branded/Non-Branded  \
# 67          Retail         Regular      Other               Other
# 69          Retail         Regular      Other               Other
# 71          Retail         Regular      Other               Other
#
#     avgPurchase  segment
# 67     0.008714        1
# 69     0.007185        1
# 71     0.005962        1

# %%
dfbsReWr[dfbsReWr['segment'] == 2].head(10)
# Out:
#          F&B Retail.x      CR    Revenue   Attd.     F&B PC    Ret PC  \
# 63  97354.92  8722.37  514.42  106591.71  6541.0  14.883798  1.333492
# 65  97354.92  8722.37  514.42  106591.71  6541.0  14.883798  1.333492
# 66  97354.92  8722.37  514.42  106591.71  6541.0  14.883798  1.333492
# 68  97354.92  8722.37  514.42  106591.71  6541.0  14.883798  1.333492
# 70  97354.92  8722.37  514.42  106591.71  6541.0  14.883798  1.333492
# 72  97354.92  8722.37  514.42  106591.71  6541.0  14.883798  1.333492
# 73  97354.92  8722.37  514.42  106591.71  6541.0  14.883798  1.333492
#
#        CR PC   Total PC source_system  qty   amount   Price Product - Cat 1  \
# 63  0.078645  16.295935      netsuite   14  2799.86  199.99          Retail
# 65  0.078645  16.295935      netsuite   26  5199.74  199.99          Retail
# 66  0.078645  16.295935      netsuite   14  2799.86  199.99          Retail
# 68  0.078645  16.295935      netsuite   20  3999.80  199.99          Retail
# ...

# %%
mark_arrays_RetailConcert
# Out:
# array([['appetize', 1.0, 1.0, ..., 'Bar', 'Non-Branded',
#         8.331250520703157e-05],
#        ['appetize', 1.0, 6.0, ..., 'Bar', 'Branded',
#         8.331250520703157e-05],
#        ['appetize', 2.0, 10.0, ..., 'Bar', 'Branded',
#         0.00016662501041406314],
#        ...,
#        ['netsuite', 1.0, 29.99, ..., 'Other', 'Other',
#         0.00010419922892570594],
#        ['netsuite', 2.0, 79.98, ..., 'Other', 'Other',
#         0.0002083984578514119],
#        ['netsuite', 1.0, 29.99, ..., 'Other', 'Other',
#         0.00010419922892570594]], dtype=object)

# %%
kproto = KPrototypes(n_clusters=3 , verbose = 2 , max_iter = 20) 
clusters = kproto.fit_predict(mark_arrays_RetailConcert,categorical=[0,4,5,6,7,8])
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 325, ncost: 514020575.8296038
# Run: 1, iteration: 2/20, moves: 92, ncost: 465455465.61061144
# Run: 1, iteration: 3/20, moves: 27, ncost: 455658871.63517684
# Run: 1, iteration: 4/20, moves: 18, ncost: 451333996.46508765
# Run: 1, iteration: 5/20, moves: 0, ncost: 451333996.46508765
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 1213, ncost: 661811537.5893092
# Run: 2, iteration: 2/20, moves: 346, ncost: 512539481.2954567
# Run: 2, iteration: 3/20, moves: 93, ncost: 463919179.08824277
# Run: 2, iteration: 4/20, moves: 27, ncost: 454178882.94029486
# Run: 2, iteration: 5/20, moves: 14, ncost: 451354688.6175506
# Run: 2, iteration: 6/20, moves: 0, ncost: 451354688.6175506
# Init: initializing centroids
# ...

# %%
print(kproto.cluster_centroids_)
# Out:
# [['25.723618090452263' '996.1133165829144' '154.2309324400002'
#   '0.002379485178958461' 'netsuite' 'Retail' 'Retail' 'Regular' 'Other'
#   'Other']
#  ['75.61224489795919' '3378.962857142857' '109.93795918367346'
#   '0.007249403651573446' 'netsuite' 'Retail' 'Retail' 'Regular' 'Other'
#   'Other']
#  ['3.0442797034662394' '67.94111200160032' '47.05432979550677'
#   '0.000299318509789819' 'netsuite' 'Retail' 'Retail' 'Regular' 'Other'
#   'Other']]

# %%
cluster_dict = []
for c in clusters:
    cluster_dict.append(c)

# %%
dfbsReCo['segment'] = cluster_dict

# %%
dfbsReCo[dfbsReCo['segment'] == 0].head(10)
# Out:
#           F&B  Retail.x       CR    Revenue    Attd.     F&B PC    Ret PC  \
# 5   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 30  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 52  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 54  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 60  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 70  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 72  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 73  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 74  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 75  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
#
#       CR PC   Total PC source_system  qty   amount   Price Product - Cat 1  \
# 5   0.32435  23.668003      appetize   79  1738.00   22.00          Retail
# ...

# %%
dfbsReCo[dfbsReCo['segment'] == 1].head(10)
# Out:
#            F&B  Retail.x       CR    Revenue    Attd.     F&B PC    Ret PC  \
# 245  222766.89  13033.67  2777.49  238578.05   9386.0  23.733954  1.388629
# 246  222766.89  13033.67  2777.49  238578.05   9386.0  23.733954  1.388629
# 247  222766.89  13033.67  2777.49  238578.05   9386.0  23.733954  1.388629
# 248  222766.89  13033.67  2777.49  238578.05   9386.0  23.733954  1.388629
# 251  222766.89  13033.67  2777.49  238578.05   9386.0  23.733954  1.388629
# 381  194762.73  14801.47  2753.93  212318.13  13012.0  14.967932  1.137525
# 382  194762.73  14801.47  2753.93  212318.13  13012.0  14.967932  1.137525
# 452  194762.73  14801.47  2753.93  212318.13  13012.0  14.967932  1.137525
# 466  193879.96   6714.84  3414.67  204009.47  16780.0  11.554229  0.400169
# 782  132427.30  27931.78  1881.18  162240.26   8469.0  15.636710   3.29812
#
#         CR PC   Total PC source_system  qty   amount   Price Product - Cat 1  \
# ...

# %%
dfbsReCo[dfbsReCo['segment'] == 2].head(10)
# Out:
#           F&B  Retail.x       CR    Revenue    Attd.     F&B PC    Ret PC  \
# 0   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 1   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 2   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 3   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 4   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 6   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 7   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 8   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 9   263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
# 10  263509.53  16684.34  3893.17  284087.04  12003.0  21.953639  1.390014
#
#       CR PC   Total PC source_system  qty  amount  Price Product - Cat 1  \
# 0   0.32435  23.668003      appetize    1     1.0    1.0          Retail
# ...
