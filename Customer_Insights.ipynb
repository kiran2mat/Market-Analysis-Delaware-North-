# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Mounted at /content/drive/

# %%
path = "drive/Shared drives/BANA CAPSTONE/Final data preps/"
overallDf = pd.read_excel(path+'Customer Insights Data.xlsx', sheet_name='Overall Satisfaction')

overallDf
# Out:
#              Location                      Survey Answers  Response Count  \
# 0   Bridgestone Arena                    Highly Satisfied             100
# 1   Bridgestone Arena                           Satisfied              56
# 2   Bridgestone Arena  Neither Satisfied nor Dissatisfied               9
# 3   Bridgestone Arena                        Dissatisfied               5
# 4   Bridgestone Arena                 Highly Dissatisfied               1
# 5          PETCO Park                           Satisfied              38
# 6          PETCO Park                    Highly Satisfied              34
# 7          PETCO Park  Neither Satisfied nor Dissatisfied               8
# 8          PETCO Park                 Highly Dissatisfied               3
# 9          PETCO Park                        Dissatisfied               1
# 10    MetLife Stadium                    Highly Satisfied              46
# 11    MetLife Stadium                           Satisfied              27
# ...

# %%
recommendDf = pd.read_excel(path+'Customer Insights Data.xlsx', sheet_name='Likelihood to Recommend')

recommendDf
# Out:
#              Location         Survey Answers  Response Count  \
# 0   Bridgestone Arena  10 - Extremely likely              86
# 1   Bridgestone Arena                      8              34
# 2   Bridgestone Arena                      9              15
# 3   Bridgestone Arena                      7              13
# 4   Bridgestone Arena                      5              10
# 5   Bridgestone Arena                      6               5
# 6   Bridgestone Arena                      4               3
# 7   Bridgestone Arena  0 - Not at all likely               2
# 8   Bridgestone Arena                      3               2
# 9   Bridgestone Arena                      2               1
# 10         PETCO Park  10 - Extremely likely              27
# 11         PETCO Park                      9              17
# 12         PETCO Park                      8              12
# 13         PETCO Park                      7              10
# ...

# %%
avlOptionDf = pd.read_excel(path+'Customer Insights Data.xlsx', sheet_name='Satisfaction w Available Option')

avlOptionDf
# Out:
#              Location                      Survey Answers  Response Count  \
# 0   Bridgestone Arena                    Highly Satisfied              64
# 1   Bridgestone Arena                           Satisfied              30
# 2   Bridgestone Arena                        Dissatisfied               5
# 3   Bridgestone Arena  Neither Satisfied nor Dissatisfied               2
# 4     MetLife Stadium                    Highly Satisfied              32
# 5     MetLife Stadium                           Satisfied              15
# 6     MetLife Stadium  Neither Satisfied nor Dissatisfied               6
# 7     MetLife Stadium                        Dissatisfied               1
# 8          PETCO Park                    Highly Satisfied              25
# 9          PETCO Park                           Satisfied              23
# 10         PETCO Park  Neither Satisfied nor Dissatisfied               3
# 11         PETCO Park                        Dissatisfied               1
# ...

# %%
speedDf = pd.read_excel(path+'Customer Insights Data.xlsx', sheet_name='Satisfaction w Speed of Service')

speedDf
# Out:
#              Location                      Survey Answers  Response Count  \
# 0   Bridgestone Arena                    Highly Satisfied              70
# 1   Bridgestone Arena                           Satisfied              27
# 2   Bridgestone Arena  Neither Satisfied nor Dissatisfied               4
# 3     MetLife Stadium                    Highly Satisfied              31
# 4     MetLife Stadium                           Satisfied              17
# 5     MetLife Stadium  Neither Satisfied nor Dissatisfied               4
# 6     MetLife Stadium                        Dissatisfied               1
# 7     MetLife Stadium                 Highly Dissatisfied               1
# 8          PETCO Park                           Satisfied              26
# 9          PETCO Park                    Highly Satisfied              23
# 10         PETCO Park  Neither Satisfied nor Dissatisfied               4
# 11          TD Garden                           Satisfied              17
# ...
