# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("MergedFromRDS.csv", encoding = "Latin-1")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (5,6,10,11,19,46,51,52,53) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#    Unnamed: 0        Date Activity     Event Name        F&B Retail.x  \
# 0           1  2021-09-09    CONCT  Blake Shelton  263509.53  16684.3
# 1           2  2021-09-09    CONCT  Blake Shelton  263509.53  16684.3
# 2           3  2021-09-09    CONCT  Blake Shelton  263509.53  16684.3
# 3           4  2021-09-09    CONCT  Blake Shelton  263509.53  16684.3
# 4           5  2021-09-09    CONCT  Blake Shelton  263509.53  16684.3
#
#         CR    Revenue    Attd.     F&B PC  ... ...32 ...33  \
# 0  3893.17  284087.04  12003.0  21.953639  ...   NaN   NaN
# 1  3893.17  284087.04  12003.0  21.953639  ...   NaN   NaN
# 2  3893.17  284087.04  12003.0  21.953639  ...   NaN   NaN
# 3  3893.17  284087.04  12003.0  21.953639  ...   NaN   NaN
# 4  3893.17  284087.04  12003.0  21.953639  ...   NaN   NaN
#
#                   Team     Location Stand Type Service Style  \
# 0  Nashville Predators  Concessions        Bar      Standard
# 1  Nashville Predators  Concessions        Bar      Standard
# ...

# %%
df = df.drop(columns = 'Unnamed: 0')

# %%
df1 = df.drop(['...26', '...27', '...28',
       '...29', '...30', '...31', '...32', '...33'], 1)

# %%
df1.head()
# Out:
#          Date Activity     Event Name        F&B Retail.x       CR    Revenue  \
# 0  2021-09-09    CONCT  Blake Shelton  263509.53  16684.3  3893.17  284087.04
# 1  2021-09-09    CONCT  Blake Shelton  263509.53  16684.3  3893.17  284087.04
# 2  2021-09-09    CONCT  Blake Shelton  263509.53  16684.3  3893.17  284087.04
# 3  2021-09-09    CONCT  Blake Shelton  263509.53  16684.3  3893.17  284087.04
# 4  2021-09-09    CONCT  Blake Shelton  263509.53  16684.3  3893.17  284087.04
#
#      Attd.     F&B PC   Ret PC  ... Product - Cat 3  Product - Cat 4  \
# 0  12003.0  21.953639  1.39001  ...       16 Ounces           No Cat
# 1  12003.0  21.953639  1.39001  ...       16 Ounces           No Cat
# 2  12003.0  21.953639  1.39001  ...       20 Ounces           No Cat
# 3  12003.0  21.953639  1.39001  ...       24 Ounces           No Cat
# 4  12003.0  21.953639  1.39001  ...       24 Ounces           No Cat
#
#                   Team     Location Stand Type Service Style  \
# ...

# %%
df1.columns
# Out:
# Index(['Date', 'Activity', 'Event Name', 'F&B', 'Retail.x', 'CR', 'Revenue',
#        'Attd.', 'F&B PC', 'Ret PC', 'CR PC', 'Total PC', 'TH_Loc',
#        'location_id', 'cost_center_name', 'source_system', 'item_name',
#        'item_id', 'is_tax_exempt', 'qty', 'amount', 'Transaction Check',
#        'Price', 'Item Cost', 'Season', 'Event - Type Category',
#        'Event - Category', 'Game Tier', 'Location - Category',
#        'Location - Sub-Category', 'Location - Concept', 'Location - Brand',
#        'Product - Cat 0', 'Product - Cat 1', 'Product - Cat 2',
#        'Product - Cat 3', 'Product - Cat 4', 'Team', 'Location', 'Stand Type',
#        'Service Style', 'Branded/Non-Branded', 'Retail.y', 'Section',
#        'Concept'],
#       dtype='object')

# %%
df1['Retail.y'].isna().sum()
# Out:
# 243367

# %%
df1['Retail.y'].unique()
# Out:
# array(['No', nan, 'yes', 'Yes', 'no', 'NO'], dtype=object)

# %%
df1['Branded/Non-Branded'].value_counts()
# Out:
# Non-Branded        539386
# Branded            160670
# Branded Partner     42009
# In House Brand      12952
# market               1330
# Name: Branded/Non-Branded, dtype: int64

# %%
df1.Activity.unique()
# Out:
# array(['CONCT', 'ICESH', 'NHLPR', 'WREST', 'NHLRG', 'RELGN', 'MUSAW',
#        'COMIC', 'EVENT', 'ICECO', 'MOTOR', 'CBKPT', 'FMILY', 'NFLPR',
#        'NFLRG', 'NFLPO', 'CFBOT', 'MLBRG', nan, 'TENNS', 'NBAPR', 'NBARG',
#        'TOURN', 'HKYOT', 'CHKOT', 'NBAPT'], dtype=object)

# %%
df2 = df1.drop(['Event Name','location_id','cost_center_name','Transaction Check','Season','Event - Type Category','Event - Category','Game Tier','Location - Category','Location - Sub-Category','Location - Concept','Location - Brand','Team','Section'], 1)

# %%
df2.head()
# Out:
#          Date Activity        F&B Retail.x       CR    Revenue    Attd.  \
# 0  2021-09-09    CONCT  263509.53  16684.3  3893.17  284087.04  12003.0
# 1  2021-09-09    CONCT  263509.53  16684.3  3893.17  284087.04  12003.0
# 2  2021-09-09    CONCT  263509.53  16684.3  3893.17  284087.04  12003.0
# 3  2021-09-09    CONCT  263509.53  16684.3  3893.17  284087.04  12003.0
# 4  2021-09-09    CONCT  263509.53  16684.3  3893.17  284087.04  12003.0
#
#       F&B PC   Ret PC    CR PC  ...  Product - Cat 1 Product - Cat 2  \
# 0  21.953639  1.39001  0.32435  ...          Bottled    Energy Drink
# 1  21.953639  1.39001  0.32435  ...         Packaged         Premium
# 2  21.953639  1.39001  0.32435  ...          Bottled           Water
# 3  21.953639  1.39001  0.32435  ...         Packaged        Domestic
# 4  21.953639  1.39001  0.32435  ...         Packaged        Domestic
#
#   Product - Cat 3 Product - Cat 4     Location Stand Type  Service Style  \
# ...

# %%
df2['Retail.y'] = df2['Retail.y'].str.upper()

# %%
df2.head()
# Out:
#          Date Activity        F&B Retail.x       CR    Revenue    Attd.  \
# 0  2021-09-09    CONCT  263509.53  16684.3  3893.17  284087.04  12003.0
# 1  2021-09-09    CONCT  263509.53  16684.3  3893.17  284087.04  12003.0
# 2  2021-09-09    CONCT  263509.53  16684.3  3893.17  284087.04  12003.0
# 3  2021-09-09    CONCT  263509.53  16684.3  3893.17  284087.04  12003.0
# 4  2021-09-09    CONCT  263509.53  16684.3  3893.17  284087.04  12003.0
#
#       F&B PC   Ret PC    CR PC  ...  Product - Cat 1 Product - Cat 2  \
# 0  21.953639  1.39001  0.32435  ...          Bottled    Energy Drink
# 1  21.953639  1.39001  0.32435  ...         Packaged         Premium
# 2  21.953639  1.39001  0.32435  ...          Bottled           Water
# 3  21.953639  1.39001  0.32435  ...         Packaged        Domestic
# 4  21.953639  1.39001  0.32435  ...         Packaged        Domestic
#
#   Product - Cat 3 Product - Cat 4     Location Stand Type  Service Style  \
# ...

# %%
dfTd = df2.loc[df['TH_Loc'] == 'TD']

# %%
df2.TH_Loc.unique()
# Out:
# array(['Bridgestone', 'Highmark', 'Metlife', 'Petco', 'TD'], dtype=object)

# %%
dfTd.head()
# Out:
#               Date Activity       F&B Retail.x       CR   Revenue   Attd.  \
# 547168  2021-09-13    WREST  175409.7        0  1051.66  176461.3  7788.0
# 547169  2021-09-13    WREST  175409.7        0  1051.66  176461.3  7788.0
# 547170  2021-09-13    WREST  175409.7        0  1051.66  176461.3  7788.0
# 547171  2021-09-13    WREST  175409.7        0  1051.66  176461.3  7788.0
# 547172  2021-09-13    WREST  175409.7        0  1051.66  176461.3  7788.0
#
#           F&B PC Ret PC     CR PC  ...  Product - Cat 1 Product - Cat 2  \
# 547168  22.52307      0  0.135036  ...         Packaged        Domestic
# 547169  22.52307      0  0.135036  ...         Packaged         Premium
# 547170  22.52307      0  0.135036  ...         Packaged           Craft
# 547171  22.52307      0  0.135036  ...         Packaged         Premium
# 547172  22.52307      0  0.135036  ...         Packaged           Craft
#
#        Product - Cat 3 Product - Cat 4     Location Stand Type  Service Style  \
# ...

# %%
dfTd.Activity.unique()
# Out:
# array(['WREST', 'TENNS', 'NHLPR', 'CONCT', 'NBAPR', 'NHLRG', 'FMILY',
#        'NBARG', 'TOURN', 'ICESH', 'HKYOT', 'CHKOT', 'NBAPT'], dtype=object)

# %%
dfTd.isna().sum().sum()
# Out:
# 361617

# %%
dfTd.columns
# Out:
# Index(['Date', 'Activity', 'F&B', 'Retail.x', 'CR', 'Revenue', 'Attd.',
#        'F&B PC', 'Ret PC', 'CR PC', 'Total PC', 'TH_Loc', 'source_system',
#        'item_name', 'item_id', 'is_tax_exempt', 'qty', 'amount', 'Price',
#        'Item Cost', 'Product - Cat 0', 'Product - Cat 1', 'Product - Cat 2',
#        'Product - Cat 3', 'Product - Cat 4', 'Location', 'Stand Type',
#        'Service Style', 'Branded/Non-Branded', 'Retail.y', 'Concept'],
#       dtype='object')

# %%
dfTd1 = dfTd.copy()

# %%
dfTd1['Branded/Non-Branded'] = dfTd1['Branded/Non-Branded'].fillna('Other')

# %%
dfTd1['Stand Type'] = dfTd1['Stand Type'].fillna('Other')

# %%
dfTd1.Activity.unique()
# Out:
# array(['WREST', 'TENNS', 'NHLPR', 'CONCT', 'NBAPR', 'NHLRG', 'FMILY',
#        'NBARG', 'TOURN', 'ICESH', 'HKYOT', 'CHKOT', 'NBAPT'], dtype=object)

# %%
dfTdAlIc1 = dfTd1.loc[(dfTd1['Activity'] == 'ICESH') & (dfTd1['Product - Cat 0'] == "Alcohol")] 
dfTdAlTn1 = dfTd1.loc[(dfTd1['Activity'] == 'TENNS') & (dfTd1['Product - Cat 0'] == "Alcohol")]

# %%
dfTdAlIc1.reset_index(inplace = True)
dfTdAlTn1.reset_index(inplace = True)

# %%
dfTdAlIc1.head()
# Out:
#     index        Date Activity      F&B Retail.x CR  Revenue   Attd.  \
# 0  753584  2022-02-23    ICESH  41562.2        0  0  41562.2  4784.0
# 1  753589  2022-02-23    ICESH  41562.2        0  0  41562.2  4784.0
# 2  753595  2022-02-23    ICESH  41562.2        0  0  41562.2  4784.0
# 3  753596  2022-02-23    ICESH  41562.2        0  0  41562.2  4784.0
# 4  753600  2022-02-23    ICESH  41562.2        0  0  41562.2  4784.0
#
#      F&B PC Ret PC  ... Product - Cat 1  Product - Cat 2 Product - Cat 3  \
# 0  8.687751      0  ...        Non-Beer          Seltzer       16 Ounces
# 1  8.687751      0  ...        Non-Beer             Wine         Regular
# 2  8.687751      0  ...           Draft         Domestic           Large
# 3  8.687751      0  ...           Draft          Premium           Large
# 4  8.687751      0  ...        Non-Beer             Wine         Regular
#
#   Product - Cat 4     Location  Stand Type Service Style  Branded/Non-Branded  \
# ...

# %%
dfTdAlTn1.head()
# Out:
#     index        Date Activity       F&B Retail.x       CR   Revenue    Attd.  \
# 0  547731  2021-09-24    TENNS  611381.9        0  53438.8  664820.7  18535.0
# 1  547732  2021-09-24    TENNS  611381.9        0  53438.8  664820.7  18535.0
# 2  547733  2021-09-24    TENNS  611381.9        0  53438.8  664820.7  18535.0
# 3  547734  2021-09-24    TENNS  611381.9        0  53438.8  664820.7  18535.0
# 4  547735  2021-09-24    TENNS  611381.9        0  53438.8  664820.7  18535.0
#
#      F&B PC Ret PC  ... Product - Cat 1  Product - Cat 2 Product - Cat 3  \
# 0  32.98527      0  ...        Non-Beer          Premium       16 Ounces
# 1  32.98527      0  ...        Packaged         Domestic       16 Ounces
# 2  32.98527      0  ...        Packaged         Domestic       16 Ounces
# 3  32.98527      0  ...        Packaged         Domestic       16 Ounces
# 4  32.98527      0  ...        Packaged            Craft       16 Ounces
#
# ...

# %%
dfTdAlIc1['avgPurchase'] = dfTdAlIc1['qty'] /dfTdAlIc1['Attd.']
dfTdAlTn1['avgPurchase'] = dfTdAlTn1['qty'] /dfTdAlTn1['Attd.']
# Out:
# <ipython-input-32-eb457f5d6e30>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfTdAlIc1['avgPurchase'] = dfTdAlIc1['qty'] /dfTdAlIc1['Attd.']
# <ipython-input-32-eb457f5d6e30>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfTdAlTn1['avgPurchase'] = dfTdAlTn1['qty'] /dfTdAlTn1['Attd.']

# %%
dftdAlIc = dfTdAlIc1.drop(['index','Item Cost','Product - Cat 0','Concept','is_tax_exempt','Activity','Date','TH_Loc','item_id','item_name','Product - Cat 4','Location','Service Style','Retail.y'],axis =1)
dftdAlTn = dfTdAlTn1.drop(['index','Item Cost','Product - Cat 0','Concept','is_tax_exempt','Activity','Date','TH_Loc','item_id','item_name','Product - Cat 4','Location','Service Style','Retail.y'],axis =1)

# %%
dftdAlIc1  = dftdAlIc.copy()
dftdAlTn1 = dftdAlTn.copy()

# %%
dftdAlIc1['Product - Cat 3'].value_counts()
# Out:
# Regular      269
# 16 Ounces     82
# Large         74
# 24 Ounces     18
# 12 Ounces     18
# 25 Ounces      8
# 187ml          7
# Small          7
# Name: Product - Cat 3, dtype: int64

# %%
dftdAlTn1['Product - Cat 3'].value_counts()
# Out:
# Regular        611
# 16 Ounces      193
# Large          117
# 375 ml          79
# 24 Ounces       46
# 12 Ounces       27
# 25 Ounces       23
# 6 Ounces        20
# 187ml           17
# 9 Ounces        15
# Small            4
# Medium           3
# 14.9 Ounces      1
# Name: Product - Cat 3, dtype: int64

# %%
dftdAlIc1 = dftdAlIc1.drop(['F&B', 'Retail.x', 'CR', 'Revenue', 'Attd.', 'F&B PC', 'Ret PC','CR PC', 'Total PC'], axis =1)
dftdAlTn1 = dftdAlTn1.drop(['F&B', 'Retail.x', 'CR', 'Revenue', 'Attd.', 'F&B PC', 'Ret PC','CR PC', 'Total PC'], axis =1)

# %%
dftdAlIc1['Product - Cat 3'] = ['Small' if ( x == '187ml' or x == 'Small' or x == '12 Ounces' ) else 'Regular' if ( x == 'Regular'  or x == '16 Ounces') else 'Large' for x in dftdAlIc1['Product - Cat 3']]
dftdAlTn1['Product - Cat 3'] = ['Small' if ( x == '187ml' or x == '375 ml' or x == 'Small' or x == '12 Ounces' or x == '6 Ounces' or x == '14.9 Ounces') else 'Regular' if ( x == 'Regular'  or x == '16 Ounces' or x == 'Medium') else 'Large' for x in dftdAlTn1['Product - Cat 3']]

# %%
dftdAlIc1.isna().sum().sum()
# Out:
# 0

# %%
dftdAlTn1.isna().sum().sum()
# Out:
# 0

# %%
from kmodes.kprototypes import KPrototypes

# %%
dftdAlIc1.head()
# Out:
#   source_system  qty  amount  Price Product - Cat 1 Product - Cat 2  \
# 0      appetize   33  363.00  11.00        Non-Beer         Seltzer
# 1      appetize    1   11.75  11.75        Non-Beer            Wine
# 2      appetize   42  619.50  14.75           Draft        Domestic
# 3      appetize   44  649.00  14.75           Draft         Premium
# 4      appetize    1   11.75  11.75        Non-Beer            Wine
#
#   Product - Cat 3 Stand Type Branded/Non-Branded  avgPurchase
# 0         Regular      Stand         Non-Branded     0.006898
# 1         Regular      Stand         Non-Branded     0.000209
# 2           Large      Stand         Non-Branded     0.008779
# 3           Large      Stand         Non-Branded     0.009197
# 4         Regular      Stand         Non-Branded     0.000209

# %%
dftdAlTn1.head()
# Out:
#   source_system  qty   amount  Price Product - Cat 1 Product - Cat 2  \
# 0      appetize   26   312.00  12.00        Non-Beer         Premium
# 1      appetize  115  1293.75  11.25        Packaged        Domestic
# 2      appetize   25   281.25  11.25        Packaged        Domestic
# 3      appetize   72   810.00  11.25        Packaged        Domestic
# 4      appetize  129  1548.00  12.00        Packaged           Craft
#
#   Product - Cat 3 Stand Type Branded/Non-Branded  avgPurchase
# 0         Regular   Portable             Branded     0.001403
# 1         Regular   Portable             Branded     0.006204
# 2         Regular   Portable             Branded     0.001349
# 3         Regular   Portable             Branded     0.003885
# 4         Regular   Portable             Branded     0.006960

# %%
mark_arrays_AlcoholTennis = dftdAlTn1.values
mark_arrays_AlcoholICESH = dftdAlIc1.values

# %%
mark_arrays_AlcoholTennis[:,1] = mark_arrays_AlcoholTennis[:,1].astype(float)
mark_arrays_AlcoholTennis[:,2] = mark_arrays_AlcoholTennis[:,2].astype(float)
mark_arrays_AlcoholTennis[:,3] = mark_arrays_AlcoholTennis[:,3].astype(float)
mark_arrays_AlcoholTennis[:,9] = mark_arrays_AlcoholTennis[:,9].astype(float)

# %%
mark_arrays_AlcoholICESH[:,1] = mark_arrays_AlcoholICESH[:,1].astype(float)
mark_arrays_AlcoholICESH[:,2] = mark_arrays_AlcoholICESH[:,2].astype(float)
mark_arrays_AlcoholICESH[:,3] = mark_arrays_AlcoholICESH[:,3].astype(float)
mark_arrays_AlcoholICESH[:,9] = mark_arrays_AlcoholICESH[:,9].astype(float)

# %%
mark_arrays_AlcoholTennis
# Out:
# array([['appetize', 26.0, 312.0, ..., 'Portable', 'Branded',
#         0.0014027515511195036],
#        ['appetize', 115.0, 1293.75, ..., 'Portable', 'Branded',
#         0.006204478014567035],
#        ['appetize', 25.0, 281.25, ..., 'Portable', 'Branded',
#         0.001348799568384138],
#        ...,
#        ['halo', 1.0, 140.0, ..., 'Other', 'Non-Branded',
#         9.036688957166094e-05],
#        ['halo', 1.0, 154.0, ..., 'Other', 'Non-Branded',
#         9.036688957166094e-05],
#        ['halo', 8.0, 58.64, ..., 'Other', 'Non-Branded',
#         0.0007229351165732876]], dtype=object)

# %%
kproto = KPrototypes(n_clusters=3 , verbose = 2 , max_iter = 20) 
clusters = kproto.fit_predict(mark_arrays_AlcoholTennis,categorical=[0,4,5,6,7,8])
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 53, ncost: 62007432.87588887
# Run: 1, iteration: 2/20, moves: 24, ncost: 58307617.51230519
# Run: 1, iteration: 3/20, moves: 26, ncost: 53258592.810048826
# Run: 1, iteration: 4/20, moves: 7, ncost: 52577393.958632424
# Run: 1, iteration: 5/20, moves: 4, ncost: 52475845.262078665
# Run: 1, iteration: 6/20, moves: 1, ncost: 52471935.82654994
# Run: 1, iteration: 7/20, moves: 1, ncost: 52469504.756243475
# ...

# %%
print(kproto.cluster_centroids_)
# Out:
# [['69.12244897959184' '1047.0051020408162' '16.64030612244898'
#   '0.0036365822535830705' 'appetize' 'Draft' 'Domestic' 'Large' 'Stand'
#   'Non-Branded']
#  ['7.355769230769231' '113.03372115384616' '21.099625'
#   '0.00042466034099175885' 'appetize' 'Non-Beer' 'Wine' 'Regular' 'Bar'
#   'Non-Branded']
#  ['192.88888888888889' '3172.7638888888887' '16.375'
#   '0.009863699844858178' 'appetize' 'Draft' 'Craft' 'Large' 'Bar'
#   'Non-Branded']]

# %%
cluster_dict = []
for c in clusters:
    cluster_dict.append(c)

# %%
dftdAlTn['segment'] = cluster_dict

# %%
dftdAlTn[dftdAlTn['segment'] == 0].head(10)
# Out:
#          F&B Retail.x       CR   Revenue    Attd.    F&B PC Ret PC    CR PC  \
# 1   611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 3   611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 4   611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 8   611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 9   611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 13  611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 14  611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 15  611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 16  611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 18  611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
#
#     Total PC source_system  qty   amount  Price Product - Cat 1  \
# 1   35.86839      appetize  115  1293.75  11.25        Packaged
# ...

# %%
dftdAlTn[dftdAlTn['segment'] == 1].head(10)
# Out:
#          F&B Retail.x       CR   Revenue    Attd.    F&B PC Ret PC    CR PC  \
# 0   611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 2   611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 5   611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 6   611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 7   611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 10  611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 11  611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 12  611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 17  611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 20  611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
#
#     Total PC source_system  qty  amount  Price Product - Cat 1  \
# 0   35.86839      appetize   26  312.00  12.00        Non-Beer
# ...

# %%
dftdAlTn[dftdAlTn['segment'] == 2].head(10)
# Out:
#           F&B Retail.x       CR   Revenue    Attd.    F&B PC Ret PC    CR PC  \
# 33   611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 52   611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 68   611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 72   611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 89   611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 135  611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 185  611381.9        0  53438.8  664820.7  18535.0  32.98527      0  2.88313
# 468  632294.4        0  48496.9  680791.2  21707.0  29.12859      0  2.23416
# 501  632294.4        0  48496.9  680791.2  21707.0  29.12859      0  2.23416
# 505  632294.4        0  48496.9  680791.2  21707.0  29.12859      0  2.23416
#
#      Total PC source_system  qty   amount  Price Product - Cat 1  \
# ...

# %%
mark_arrays_AlcoholICESH
# Out:
# array([['appetize', 33.0, 363.0, ..., 'Stand', 'Non-Branded',
#         0.006897993311036789],
#        ['appetize', 1.0, 11.75, ..., 'Stand', 'Non-Branded',
#         0.00020903010033444816],
#        ['appetize', 42.0, 619.5, ..., 'Stand', 'Non-Branded',
#         0.008779264214046822],
#        ...,
#        ['halo', 1.0, 140.0, ..., 'Other', 'Non-Branded',
#         8.19000819000819e-05],
#        ['halo', 5.0, 240.0, ..., 'Other', 'Non-Branded',
#         0.0004095004095004095],
#        ['halo', 12.0, 87.96, ..., 'Other', 'Non-Branded',
#         0.0009828009828009828]], dtype=object)

# %%
kproto = KPrototypes(n_clusters=3 , verbose = 2 , max_iter = 20) 
clusters = kproto.fit_predict(mark_arrays_AlcoholICESH,categorical=[0,4,5,6,7,8])
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 33, ncost: 12383322.737704903
# Run: 1, iteration: 2/20, moves: 29, ncost: 10147976.25523886
# Run: 1, iteration: 3/20, moves: 8, ncost: 9896111.501410136
# Run: 1, iteration: 4/20, moves: 0, ncost: 9896111.501410136
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 51, ncost: 12797673.435626961
# Run: 2, iteration: 2/20, moves: 25, ncost: 10959693.517258579
# Run: 2, iteration: 3/20, moves: 18, ncost: 9900993.42829836
# Run: 2, iteration: 4/20, moves: 2, ncost: 9896111.501410136
# Run: 2, iteration: 5/20, moves: 0, ncost: 9896111.501410136
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# ...

# %%
print(kproto.cluster_centroids_)
# Out:
# [['5.133507853403142' '70.37379581151832' '19.495842984293194'
#   '0.0005303796756633634' 'appetize' 'Non-Beer' 'Wine' 'Regular' 'Stand'
#   'Non-Branded']
#  ['108.8' '1559.61' '14.47' '0.007837460022867728' 'appetize' 'Draft'
#   'Domestic' 'Large' 'Stand' 'Non-Branded']
#  ['43.6578947368421' '604.2697368421053' '15.516560789473685'
#   '0.004206123319518387' 'appetize' 'Draft' 'Domestic' 'Large' 'Stand'
#   'Non-Branded']]

# %%
cluster_dict = []
for c in clusters:
    cluster_dict.append(c)

# %%
dftdAlIc['segment'] = cluster_dict

# %%
dftdAlIc[dftdAlIc['segment'] == 0].head(10)
# Out:
#         F&B Retail.x CR  Revenue   Attd.    F&B PC Ret PC CR PC  Total PC  \
# 1   41562.2        0  0  41562.2  4784.0  8.687751      0     0  8.687751
# 4   41562.2        0  0  41562.2  4784.0  8.687751      0     0  8.687751
# 6   41562.2        0  0  41562.2  4784.0  8.687751      0     0  8.687751
# 7   41562.2        0  0  41562.2  4784.0  8.687751      0     0  8.687751
# 8   41562.2        0  0  41562.2  4784.0  8.687751      0     0  8.687751
# 10  41562.2        0  0  41562.2  4784.0  8.687751      0     0  8.687751
# 11  41562.2        0  0  41562.2  4784.0  8.687751      0     0  8.687751
# 12  41562.2        0  0  41562.2  4784.0  8.687751      0     0  8.687751
# 13  41562.2        0  0  41562.2  4784.0  8.687751      0     0  8.687751
# 14  41562.2        0  0  41562.2  4784.0  8.687751      0     0  8.687751
#
#    source_system  qty  amount  Price Product - Cat 1 Product - Cat 2  \
# 1       appetize    1   11.75  11.75        Non-Beer            Wine
# ...

# %%
dftdAlIc[dftdAlIc['segment'] == 1].head(10)
# Out:
#            F&B Retail.x       CR    Revenue    Attd.    F&B PC Ret PC  \
# 84   101694.30        0        0  101694.30  13242.0  7.679681      0
# 89   101694.30        0        0  101694.30  13242.0  7.679681      0
# 103  101694.30        0        0  101694.30  13242.0  7.679681      0
# 163   82265.76        0        0   82265.76   9214.0  8.928344      0
# 167   82265.76        0        0   82265.76   9214.0  8.928344      0
# 171   82265.76        0        0   82265.76   9214.0  8.928344      0
# 184   82265.76        0        0   82265.76   9214.0  8.928344      0
# 249  164334.90        0  1613.88  165948.80  17347.0  9.473391      0
# 252  164334.90        0  1613.88  165948.80  17347.0  9.473391      0
# 253  164334.90        0  1613.88  165948.80  17347.0  9.473391      0
#
#          CR PC  Total PC source_system  qty   amount  Price Product - Cat 1  \
# 84           0  7.679681      appetize   94  1386.50  14.75           Draft
# ...

# %%
dftdAlIc[dftdAlIc['segment'] == 2].head(10)
# Out:
#         F&B Retail.x CR  Revenue   Attd.    F&B PC Ret PC CR PC  Total PC  \
# 0   41562.2        0  0  41562.2  4784.0  8.687751      0     0  8.687751
# 2   41562.2        0  0  41562.2  4784.0  8.687751      0     0  8.687751
# 3   41562.2        0  0  41562.2  4784.0  8.687751      0     0  8.687751
# 5   41562.2        0  0  41562.2  4784.0  8.687751      0     0  8.687751
# 9   41562.2        0  0  41562.2  4784.0  8.687751      0     0  8.687751
# 16  41562.2        0  0  41562.2  4784.0  8.687751      0     0  8.687751
# 22  41562.2        0  0  41562.2  4784.0  8.687751      0     0  8.687751
# 23  41562.2        0  0  41562.2  4784.0  8.687751      0     0  8.687751
# 34  41562.2        0  0  41562.2  4784.0  8.687751      0     0  8.687751
# 38  41562.2        0  0  41562.2  4784.0  8.687751      0     0  8.687751
#
#    source_system  qty  amount  Price Product - Cat 1 Product - Cat 2  \
# 0       appetize   33  363.00  11.00        Non-Beer         Seltzer
# ...
